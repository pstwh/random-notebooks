# %% [markdown]
# <img src="data:image/png;base64,..." style="width: 600px">

# %%
import pandas as pd

# %%
df = pd.read_csv('random-data/simtempos.csv', )

# %%
df.head()
# Out:
#    Inicio Procesos  Comprar Ticket  Entregar Ticket  Servir  Comer  \
# 0               22             166               95      60    624
# 1               19             146               65      32    834
# 2               30             155              105      21    727
# 3               24             155               86      48    366
# 4               40              83               75      54    617
#
#    Entregar Bandeja
# 0                54
# 1                44
# 2                18
# 3                58
# 4                31

# %% [markdown]
# <h3> 01) Chama rotina de inicialização </h3>
#
# <p> Nesse processo é iniciada a simulação, sendo definido o tempo de relógio para um, definidos os estados, contadores e estatísticas </p>
#
# <img src="data:image/png;base64,..." style="height: 500px"/>

# %% [markdown]
# <h3> 02) Chama rotina de avanço do tempo tempo </h3>
#
# <p> Determina o avanço do tempo, e o próximo evento, no caso da simulação do restaurante universitário tempos:

# %% [markdown]
# <p>Depois da etapa de inicialização, temos a atualização em loop, com avanço no tempo. Quando um evento for ativado, teremos a ativação da rotina </p>

# %% [markdown]
# <img src="data:image/png;base64,..."style="height: 500px"/>

# %% [markdown]
# <p> Quando o evento dispara, e a entidade se move no grafo de estados </p>

# %% [markdown]
# <h2> Simulando manualmente o processo de restaurante universitário </h2>

# %% [markdown]
# <h4> Início do Processo </h4>
# <p> A <b>primeira entidade</b> ativada o evento de chegada e demora 30 segundos no processo</p>

# %%
df["Inicio Procesos"][0]
# Out:
# 22

# %% [markdown]
# <h4> Início do Processo </h4>
# <p> A <b>segunda entidade</b> ativada o evento de chegada e demora 22 segundos no processo</p>

# %%
df["Inicio Procesos"][1]
# Out:
# 19

# %% [markdown]
# <h4> Início do Processo </h4>
# <p> A <b>terceira entidade</b> ativada o evento de chegada e demora 19 segundos no processo</p>

# %%
df["Inicio Procesos"][2]
# Out:
# 30

# %% [markdown]
# <h4> Início do Processo </h4>
# <p> A <b>quarta entidade</b> ativada o evento de chegada e demora 30 segundos no processo</p>

# %%
df["Inicio Procesos"][3]
# Out:
# 24

# %% [markdown]
# <h4> Início do Processo </h4>
# <p> A <b>quinta entidade</b> ativada o evento de chegada e demora 30 segundos no processo</p>

# %%
df["Inicio Procesos"][4]
# Out:
# 40

# %% [markdown]
# <p> Na etapa de chegada não há fila, porém temos o avanço no tempo e disparo do evento de compra de ticket das entidades </p>

# %% [markdown]
# <h4> Comprar ticket </h4>
# <p> A <b>primeira entidade</b> ativada o evento de chegada e demora 166 segundos no processo</p>

# %%
df["Comprar Ticket"][0]
# Out:
# 166

# %% [markdown]
# <h4> Comprar ticket </h4>
# <p> A <b>segunda entidade</b> ativada o evento de chegada e demora 146 segundos no processo</p>

# %%
df["Comprar Ticket"][1]
# Out:
# 146

# %% [markdown]
# <h4> Comprar ticket </h4>
# <p> A <b>terceira entidade</b> ativada o evento de chegada e demora 155 segundos no processo</p>

# %%
df["Comprar Ticket"][2]
# Out:
# 155

# %% [markdown]
# <h4> Comprar ticket </h4>
# <p> A <b>quarta entidade</b> ativada o evento de chegada e demora 155 segundos no processo</p>

# %%
df["Comprar Ticket"][3]
# Out:
# 155

# %% [markdown]
# <h4> Comprar ticket </h4>
# <p> A <b>quinta entidade</b> ativada o evento de chegada e demora 83 segundos no processo</p>

# %%
df["Comprar Ticket"][4]
# Out:
# 83

# %% [markdown]
# <p> Na etapa de compra de tickets, tempos fila devido a linearidade do processo. Uma entidade deve esperar o termino de outra entidade </p>
