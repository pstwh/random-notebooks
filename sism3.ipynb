# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

import scipy
from scipy import stats
from itertools import groupby

# %matplotlib inline

# %%
data = np.random.randint(0, 20, 1000)

# %%
data[:10]
# Out:
# array([ 8,  3,  5, 16,  7, 14, 13,  1,  8,  9])

# %%
x, y = np.unique(data, return_counts=True)

# %%
n, bins, patches = plt.hist(data, 20, normed=1, facecolor='green', alpha=0.75)

dists = [ 'alpha', 'anglit', 'arcsine', 'beta', 'betaprime', 'bradford', 'burr', 'cauchy', 'chi', 'chi2', 'cosine', 'dgamma', 'dweibull', 'expon', 'exponweib', 'exponpow', 'f', 'fatiguelife', 'fisk', 'foldcauchy', 'foldnorm', 'frechet_r', 'frechet_l', 'genlogistic', 'genpareto', 'genexpon', 'genextreme', 'gausshyper', 'gamma', 'gengamma', 'genhalflogistic', 'gilbrat', 'gompertz', 'gumbel_r', 'gumbel_l', 'halfcauchy', 'halflogistic', 'halfnorm', 'hypsecant', 'invgamma', 'invgauss', 'invweibull', 'johnsonsb', 'johnsonsu', 'ksone', 'kstwobign', 'laplace', 'logistic', 'loggamma', 'loglaplace', 'lognorm', 'lomax', 'maxwell', 'mielke', 'nakagami', 'ncx2', 'ncf', 'nct', 'norm', 'pareto', 'pearson3', 'powerlaw', 'powerlognorm', 'powernorm', 'rdist', 'reciprocal', 'rayleigh', 'rice', 'recipinvgauss', 'semicircular', 't', 'triang', 'truncexpon', 'truncnorm', 'tukeylambda', 'uniform', 'vonmises', 'wald', 'weibull_min', 'weibull_max', 'wrapcauchy'] 
#dists = ['gamma', 'beta', 'rayleigh', 'norm', 'pareto']
plt.figure(figsize=(12,8))
h = plt.hist(y, bins=range(20), color='w')

for dist in dists:
    dist = getattr(scipy.stats, dist)
    param = dist.fit(data)
    fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1]) * size
    plt.grid(True)
    plt.figure(figsize=(12,8))
    plt.plot(fitted, label=dist)

"""
(mu, sigma) = stats.norm.fit(data)
l = plt.plot(bins, y, 'r--', linewidth=2)

plt.title(r'$\mathrm{Histograma:}\ \mu=%.3f,\ \sigma=%.3f$' %(mu, sigma))
plt.grid(True)
plt.show()
"""
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:2306: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:304: RuntimeWarning: divide by zero encountered in true_divide
#   return 1.0/np.pi/np.sqrt(x*(1-x))
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:580: RuntimeWarning: divide by zero encountered in true_divide
#   a/(b-1.0),
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:584: RuntimeWarning: divide by zero encountered in true_divide
#   a*(a+1.0)/((b-2.0)*(b-1.0)),
# ...
